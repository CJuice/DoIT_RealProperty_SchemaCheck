# %%
import seaborn as sns
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
boolean_dtypes_file = r"..\data\20200707_QUEE_FME_output_dtypes_boolean.xlsx"
assert os.path.exists(boolean_dtypes_file)

# %%
df = pd.read_excel(boolean_dtypes_file, index_col="chunk_round")

# %%
f, ax = plt.subplots(figsize=(60, 6))
heatmap = sns.heatmap(data=df, cmap="Paired", ax=ax)
plt.savefig(r"..\data\test.png")
